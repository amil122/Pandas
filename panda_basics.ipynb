# %%
import pandas as pd
import numpy as np

# %%
#create from a list
s1 =pd.Series(['mini','john','manu'])
s1
# Out:
# 0    mini
# 1    john
# 2    manu
# dtype: object

# %%
s2 = pd.Series(np.random.randint(1,10,size =5),index = ['a','b','c','d','e'])
s2
# Out:
# a    7
# b    3
# c    3
# d    7
# e    6
# dtype: int32

# %%
d = {'a':1,'b':2,'c':3}
s3 = pd.Series(d)
s3
# Out:
# a    1
# b    2
# c    3
# dtype: int64

# %%
s4 = pd.Series(10,index= ['a','b','c','d','f'])
s4
# Out:
# a    10
# b    10
# c    10
# d    10
# f    10
# dtype: int64

# %%
# here index_col is used to give a default index while loading
df = pd.read_csv('data_sets/data/survey_results_public.csv',index_col='ResponseId')

# %%
#to get the directory 
import os
os.getcwd()
# Out:
# 'C:\\Users\\amil\\OneDrive\\Documents\\Pandas\\Pandas_basics'

# %%
df
# Out:
#                Q120                      MainBranch                 Age  \
# ResponseId
# 1           I agree                   None of these     18-24 years old
# 2           I agree  I am a developer by profession     25-34 years old
# 3           I agree  I am a developer by profession     45-54 years old
# 4           I agree  I am a developer by profession     25-34 years old
# 5           I agree  I am a developer by profession     25-34 years old
# ...             ...                             ...                 ...
# 89180       I agree  I am a developer by profession     25-34 years old
# 89181       I agree  I am a developer by profession     18-24 years old
# 89182       I agree     I code primarily as a hobby   Prefer not to say
# 89183       I agree  I am a developer by profession  Under 18 years old
# 89184       I agree  I am a developer by profession     35-44 years old
#
#                                                    Employment  \
# ResponseId
# ...

# %%
df.shape
# Out:
# (89184, 83)

# %%
# info methods gives the overall inforamtion about the data sets
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 89184 entries, 1 to 89184
# Data columns (total 83 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Q120                                 89184 non-null  object
#  1   MainBranch                           89184 non-null  object
#  2   Age                                  89184 non-null  object
#  3   Employment                           87898 non-null  object
#  4   RemoteWork                           73810 non-null  object
#  5   CodingActivities                     73764 non-null  object
#  6   EdLevel                              87973 non-null  object
#  7   LearnCode                            87663 non-null  object
#  8   LearnCodeOnline                      70084 non-null  object
#  9   LearnCodeCoursesCert                 37076 non-null  object
#  10  YearsCode                            87435 non-null  object
# ...

# %%
# it's used for see the full columns in the data sets
pd.set_option('display.max_columns',85)

# %%
schema_df = pd.read_csv('data_sets/data/survey_results_schema.csv',index_col = 'qid')

# %%
schema_df
# Out:
#               qname                                           question  \
# qid
# QID16            S0  <div><span style="font-size:19px;"><strong>Hel...
# QID12      MetaInfo                                  Browser Meta Info
# QID310         Q310  <div><span style="font-size:19px;"><strong>You...
# QID312         Q120
# QID1             S1  <span style="font-size:22px; font-family: aria...
# ...             ...                                                ...
# QID289  Knowledge_7  Waiting on answers to questions often causes i...
# QID289  Knowledge_8  I feel like I have the tools and/or resources ...
# QID290  Frequency_1  Needing help from people outside of your immed...
# QID290  Frequency_2  Interacting with people outside of your immedi...
# QID290  Frequency_3  Encountering knowledge silos (where one indivi...
#
#        force_resp  type selector
# qid
# QID16       False    DB       TB
# QID12       False  Meta  Browser
# QID310      False    DB       TB
# ...

# %%
pd.set_option('display.width',1000)

# %%
schema_df
# Out:
#               qname                                           question force_resp  type selector
# qid
# QID16            S0  <div><span style="font-size:19px;"><strong>Hel...      False    DB       TB
# QID12      MetaInfo                                  Browser Meta Info      False  Meta  Browser
# QID310         Q310  <div><span style="font-size:19px;"><strong>You...      False    DB       TB
# QID312         Q120                                                          True    MC     SAVR
# QID1             S1  <span style="font-size:22px; font-family: aria...      False    DB       TB
# ...             ...                                                ...        ...   ...      ...
# QID289  Knowledge_7  Waiting on answers to questions often causes i...        NaN    MC     MAVR
# QID289  Knowledge_8  I feel like I have the tools and/or resources ...        NaN    MC     MAVR
# QID290  Frequency_1  Needing help from people outside of your immed...        NaN    MC     MAVR
# ...

# %%
pd.set_option('display.max_rows',78)

# %%
schema_df
# Out:
#                        qname                                           question force_resp    type selector
# qid
# QID16                     S0  <div><span style="font-size:19px;"><strong>Hel...      False      DB       TB
# QID12               MetaInfo                                  Browser Meta Info      False    Meta  Browser
# QID310                  Q310  <div><span style="font-size:19px;"><strong>You...      False      DB       TB
# QID312                  Q120                                                          True      MC     SAVR
# QID1                      S1  <span style="font-size:22px; font-family: aria...      False      DB       TB
# QID2              MainBranch  Which of the following options best describes ...       True      MC     SAVR
# QID127                   Age                                What is your age? *       True      MC     MAVR
# QID296            Employment  Which of the following best describes your cur...      False      MC     MAVR
# ...

# %%
#to see the first n number of values then we will use head
df.head(20)
# Out:
#                Q120                                         MainBranch                 Age                                         Employment                            RemoteWork                                   CodingActivities                                            EdLevel                                          LearnCode                                    LearnCodeOnline                    LearnCodeCoursesCert YearsCode      YearsCodePro                                        DevType                                            OrgSize                 PurchaseInfluence      TechList                                         BuyNewTool                                            Country                   Currency  CompTotal                             LanguageHaveWorkedWith                             LanguageWantToWorkWith                             DatabaseHaveWorkedWith                             DatabaseWantToWorkWith                             PlatformHaveWorkedWith  \
# ...

# %%
#and for last n number of values then we will use tail
df.tail()
# Out:
#                Q120                      MainBranch                 Age                                         Employment                            RemoteWork                                   CodingActivities                                            EdLevel                                          LearnCode                                    LearnCodeOnline             LearnCodeCoursesCert YearsCode YearsCodePro                DevType               OrgSize      PurchaseInfluence     TechList                                         BuyNewTool                       Country             Currency     CompTotal                             LanguageHaveWorkedWith                             LanguageWantToWorkWith                             DatabaseHaveWorkedWith                             DatabaseWantToWorkWith                             PlatformHaveWorkedWith                             PlatformWantToWorkWith                             WebframeHaveWorkedWith  \
# ResponseId
# ...

# %%
people ={'first': ['muhammed','amil','jaseel'],
        'last' : ['basil','pranav','akhil'],
        'city':['kochi','kannur','blr']}
pd = pd.DataFrame(people)

# %%
pd
# Out:
#       first    last    city
# 0  muhammed   basil   kochi
# 1      amil  pranav  kannur
# 2    jaseel   akhil     blr

# %%
pd['first']
# Out:
# 0    muhammed
# 1        amil
# 2      jaseel
# Name: first, dtype: object

# %%
pd['first'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 3 entries, 0 to 2
# Series name: first
# Non-Null Count  Dtype
# --------------  -----
# 3 non-null      object
# dtypes: object(1)
# memory usage: 156.0+ bytes

# %%
pd['first'].shape
# Out:
# (3,)

# %%
type(pd['city'])
# Out:
# pandas.core.series.Series

# %%
pd.city
# Out:
# 0     kochi
# 1    kannur
# 2       blr
# Name: city, dtype: object

# %%
df.count
# Out:
# <bound method DataFrame.count of                Q120                      MainBranch                 Age                                         Employment                            RemoteWork                                   CodingActivities                                            EdLevel                                          LearnCode                                    LearnCodeOnline             LearnCodeCoursesCert YearsCode YearsCodePro                               DevType                   OrgSize                 PurchaseInfluence      TechList                                         BuyNewTool                       Country                   Currency     CompTotal                             LanguageHaveWorkedWith                             LanguageWantToWorkWith                             DatabaseHaveWorkedWith                             DatabaseWantToWorkWith                             PlatformHaveWorkedWith                             PlatformWantToWorkWith  \
# ...

# %%
pd.count
# Out:
# <bound method DataFrame.count of       first    last    city
# 0  muhammed   basil   kochi
# 1      amil  pranav  kannur
# 2    jaseel   akhil     blr>

# %%
df.count
# Out:
# <bound method DataFrame.count of                Q120                      MainBranch                 Age  \
# ResponseId
# 1           I agree                   None of these     18-24 years old
# 2           I agree  I am a developer by profession     25-34 years old
# 3           I agree  I am a developer by profession     45-54 years old
# 4           I agree  I am a developer by profession     25-34 years old
# 5           I agree  I am a developer by profession     25-34 years old
# ...             ...                             ...                 ...
# 89180       I agree  I am a developer by profession     25-34 years old
# 89181       I agree  I am a developer by profession     18-24 years old
# 89182       I agree     I code primarily as a hobby   Prefer not to say
# 89183       I agree  I am a developer by profession  Under 18 years old
# 89184       I agree  I am a developer by profession     35-44 years old
#
# ...

# %%
import pandas as pd
df = pd.read_csv('data_sets/data/survey_results_public.csv')

# %%
df[['RemoteWork','Age']]
# Out:
#                                  RemoteWork                 Age
# 0                                       NaN     18-24 years old
# 1                                    Remote     25-34 years old
# 2      Hybrid (some remote, some in-person)     45-54 years old
# 3      Hybrid (some remote, some in-person)     25-34 years old
# 4                                    Remote     25-34 years old
# ...                                     ...                 ...
# 89179                                Remote     25-34 years old
# 89180  Hybrid (some remote, some in-person)     18-24 years old
# 89181                                   NaN   Prefer not to say
# 89182  Hybrid (some remote, some in-person)  Under 18 years old
# 89183  Hybrid (some remote, some in-person)     35-44 years old
#
# [89184 rows x 2 columns]

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.columns
# Out:
# Index(['ResponseId', 'Q120', 'MainBranch', 'Age', 'Employment', 'RemoteWork', 'CodingActivities', 'EdLevel', 'LearnCode', 'LearnCodeOnline', 'LearnCodeCoursesCert', 'YearsCode', 'YearsCodePro', 'DevType', 'OrgSize', 'PurchaseInfluence', 'TechList', 'BuyNewTool', 'Country', 'Currency', 'CompTotal', 'LanguageHaveWorkedWith', 'LanguageWantToWorkWith', 'DatabaseHaveWorkedWith', 'DatabaseWantToWorkWith', 'PlatformHaveWorkedWith', 'PlatformWantToWorkWith', 'WebframeHaveWorkedWith', 'WebframeWantToWorkWith', 'MiscTechHaveWorkedWith', 'MiscTechWantToWorkWith', 'ToolsTechHaveWorkedWith', 'ToolsTechWantToWorkWith', 'NEWCollabToolsHaveWorkedWith', 'NEWCollabToolsWantToWorkWith', 'OpSysPersonal use', 'OpSysProfessional use', 'OfficeStackAsyncHaveWorkedWith', 'OfficeStackAsyncWantToWorkWith', 'OfficeStackSyncHaveWorkedWith', 'OfficeStackSyncWantToWorkWith', 'AISearchHaveWorkedWith', 'AISearchWantToWorkWith', 'AIDevHaveWorkedWith', 'AIDevWantToWorkWith', 'NEWSOSites', 'SOVisitFreq', 'SOAccount',
# ...

# %%
df[['MainBranch','Age']]
# Out:
#                            MainBranch                 Age
# 0                       None of these     18-24 years old
# 1      I am a developer by profession     25-34 years old
# 2      I am a developer by profession     45-54 years old
# 3      I am a developer by profession     25-34 years old
# 4      I am a developer by profession     25-34 years old
# ...                               ...                 ...
# 89179  I am a developer by profession     25-34 years old
# 89180  I am a developer by profession     18-24 years old
# 89181     I code primarily as a hobby   Prefer not to say
# 89182  I am a developer by profession  Under 18 years old
# 89183  I am a developer by profession     35-44 years old
#
# [89184 rows x 2 columns]

# %%
#The iloc method is used to access a group of rows and columns by integer positions. It is position-based, meaning that you have to specify the row and column indices.
df.iloc[0:3,'MainBranch']
# Out:
# 0                     None of these
# 1    I am a developer by profession
# 2    I am a developer by profession
# 3    I am a developer by profession
# Name: MainBranch, dtype: object

# %%
df.iloc[[0,29]]
# Out:
#     ResponseId     Q120                      MainBranch              Age           Employment RemoteWork               CodingActivities                              EdLevel                                          LearnCode LearnCodeOnline LearnCodeCoursesCert YearsCode YearsCodePro              DevType                   OrgSize              PurchaseInfluence TechList                                         BuyNewTool Country           Currency  CompTotal              LanguageHaveWorkedWith                 LanguageWantToWorkWith  DatabaseHaveWorkedWith DatabaseWantToWorkWith                             PlatformHaveWorkedWith                             PlatformWantToWorkWith                WebframeHaveWorkedWith       WebframeWantToWorkWith MiscTechHaveWorkedWith MiscTechWantToWorkWith                            ToolsTechHaveWorkedWith                            ToolsTechWantToWorkWith          NEWCollabToolsHaveWorkedWith          NEWCollabToolsWantToWorkWith OpSysPersonal use  \
# ...

# %%
# in here we getting the value from index 0 and 29 and 2nd paramenter 3 was indicating that index of the column you want with that rows 
df.iloc[[0,29], 3]
# Out:
# 0     18-24 years old
# 29    35-44 years old
# Name: Age, dtype: object

# %%
#print(df.mean())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 print(df.mean())
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:11335, in DataFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   11327 @doc(make_doc("mean", ndim=2))
#   11328 def mean(
#   11329     self,
#    (...)
#   11333     **kwargs,
#   11334 ):
# > 11335     result = super().mean(axis, skipna, numeric_only, **kwargs)
#   11336     if isinstance(result, Series):
#   11337         result = result.__finalize__(self, method="mean")
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:11992, in NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   11985 def mean(
#   11986     self,
#   11987     axis: Axis | None = 0,
#    (...)
#   11990     **kwargs,
#   11991 ) -> Series | float:
# > 11992     return self._stat_function(
# ...

# %% [markdown]
# numerical_df = df.select_dtypes(include= ['number'])

# %%
# numerical_df.mean()

# %%
#The loc method is used to access a group of rows and columns by labels or a boolean array. It is label-based, meaning that you have to specify the names of the rows and columns that you want to access.
df.loc[[44,22],'MainBranch']
# Out:
# 44    I am a developer by profession
# 22    I am a developer by profession
# Name: MainBranch, dtype: object

# %%
df.loc[[32,422],['MainBranch','Age']]
# Out:
#                          MainBranch              Age
# 32   I am a developer by profession  25-34 years old
# 422  I am a developer by profession  25-34 years old

# %%
df['Age']
# Out:
# 0           18-24 years old
# 1           25-34 years old
# 2           45-54 years old
# 3           25-34 years old
# 4           25-34 years old
#                 ...
# 89179       25-34 years old
# 89180       18-24 years old
# 89181     Prefer not to say
# 89182    Under 18 years old
# 89183       35-44 years old
# Name: Age, Length: 89184, dtype: object

# %%
df[['Age','MainBranch']]
# Out:
#                       Age                      MainBranch
# 0         18-24 years old                   None of these
# 1         25-34 years old  I am a developer by profession
# 2         45-54 years old  I am a developer by profession
# 3         25-34 years old  I am a developer by profession
# 4         25-34 years old  I am a developer by profession
# ...                   ...                             ...
# 89179     25-34 years old  I am a developer by profession
# 89180     18-24 years old  I am a developer by profession
# 89181   Prefer not to say     I code primarily as a hobby
# 89182  Under 18 years old  I am a developer by profession
# 89183     35-44 years old  I am a developer by profession
#
# [89184 rows x 2 columns]

# %%
 #value_counts is used to get the count of the values
df[['Age','MainBranch']].value_counts()
# Out:
# Age                 MainBranch
# 25-34 years old     I am a developer by profession                                                           28848
# 35-44 years old     I am a developer by profession                                                           17304
# 18-24 years old     I am a developer by profession                                                           11002
# 45-54 years old     I am a developer by profession                                                            6487
# 18-24 years old     I am learning to code                                                                     2733
# 25-34 years old     I am not primarily a developer, but I write code sometimes as part of my work/studies     2521
# 55-64 years old     I am a developer by profession                                                            2449
# 18-24 years old     I am not primarily a developer, but I write code sometimes as part of my work/studies     2396
# ...

# %%
#using slicing in loc
df.loc[0:15,'MainBranch']
# Out:
# 0                                         None of these
# 1                        I am a developer by profession
# 2                        I am a developer by profession
# 3                        I am a developer by profession
# 4                        I am a developer by profession
# 5                        I am a developer by profession
# 6                        I am a developer by profession
# 7                        I am a developer by profession
# 8     I am not primarily a developer, but I write co...
# 9                        I am a developer by profession
# 10                       I am a developer by profession
# 11                       I am a developer by profession
# 12                       I am a developer by profession
# 13    I am not primarily a developer, but I write co...
# 14                       I am a developer by profession
# 15                       I am a developer by profession
# Name: MainBranch, dtype: object

# %%
df.iloc[0:22,5:10]
# Out:
#                               RemoteWork                                   CodingActivities                                            EdLevel                                          LearnCode                                    LearnCodeOnline
# 0                                    NaN                                                NaN                                                NaN                                                NaN                                                NaN
# 1                                 Remote  Hobby;Contribute to open-source projects;Boots...       Bachelor’s degree (B.A., B.S., B.Eng., etc.)  Books / Physical media;Colleague;Friend or fam...  Formal documentation provided by the owner of ...
# 2   Hybrid (some remote, some in-person)  Hobby;Professional development or self-paced l...       Bachelor’s degree (B.A., B.S., B.Eng., etc.)  Books / Physical media;Colleague;On the job tr...  Formal documentation provided by the owner of ...
# ...

# %%
df.loc[4:45,['Age']]
# Out:
#                    Age
# 4      25-34 years old
# 5      35-44 years old
# 6      35-44 years old
# 7      25-34 years old
# 8      45-54 years old
# 9      25-34 years old
# 10     25-34 years old
# 11     25-34 years old
# 12     25-34 years old
# 13     35-44 years old
# 14     25-34 years old
# 15     35-44 years old
# 16     35-44 years old
# 17     25-34 years old
# 18  Under 18 years old
# 19     35-44 years old
# 20     25-34 years old
# 21     25-34 years old
# 22     25-34 years old
# 23     25-34 years old
# 24     35-44 years old
# 25     35-44 years old
# 26     25-34 years old
# 27     35-44 years old
# 28     35-44 years old
# 29     35-44 years old
# 30     35-44 years old
# 31     25-34 years old
# 32     25-34 years old
# 33     25-34 years old
# 34     35-44 years old
# 35     35-44 years old
# 36     55-64 years old
# 37     25-34 years old
# 38     25-34 years old
# 39     25-34 years old
# 40     18-24 years old
# 41     25-34 years old
# 42     45-54 years old
# ...

# %% [markdown]
# # indexes

# %%
peoples = {
    'first':['muhammed','jaseem','john','dane'],
    'last':['amil','muhammed','abraham','sd'],
    'city':['kannur','bangalore','calicut','thrissur']
}
pd_people = pd.DataFrame(peoples)

# %%
pd_people
# Out:
#       first      last       city
# 0  muhammed      amil     kannur
# 1    jaseem  muhammed  bangalore
# 2      john   abraham    calicut
# 3      dane        sd   thrissur

# %%
pd_people.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
# set_index is used to set the index for df, and if youu don't us the inplace = 'true' then it won't effect to uur data frame,so inplace is used to make the changes in the orginal data frame
pd_people.set_index('city', inplace = True)

# %%
pd_people.loc['kannur',['first','last']]
# Out:
# first    muhammed
# last         amil
# Name: kannur, dtype: object

# %%
pd_people
# Out:
#       first      last       city
# 0  muhammed      amil     kannur
# 1    jaseem  muhammed  bangalore
# 2      john   abraham    calicut
# 3      dane        sd   thrissur

# %%
pd_people.loc['calicut']
# Out:
# first       john
# last     abraham
# Name: calicut, dtype: object

# %%
#The reset_index method moves the current index back to columns and resets the index to the default integer index.
pd_people.reset_index(inplace = True)

# %%
pd_people
# Out:
#         city     first      last
# 0     kannur  muhammed      amil
# 1  bangalore    jaseem  muhammed
# 2    calicut      john   abraham
# 3   thrissur      dane        sd

# %%
df
# Out:
#        ResponseId     Q120                      MainBranch                 Age                                         Employment                            RemoteWork                                   CodingActivities                                            EdLevel                                          LearnCode                                    LearnCodeOnline             LearnCodeCoursesCert YearsCode YearsCodePro                               DevType                   OrgSize                 PurchaseInfluence      TechList                                         BuyNewTool                       Country                   Currency     CompTotal                             LanguageHaveWorkedWith                             LanguageWantToWorkWith                             DatabaseHaveWorkedWith                             DatabaseWantToWorkWith                             PlatformHaveWorkedWith                             PlatformWantToWorkWith  \
# ...

# %%
df.set_index('ResponseId', inplace = True)

# %%
df
# Out:
#                Q120                      MainBranch                 Age                                         Employment                            RemoteWork                                   CodingActivities                                            EdLevel                                          LearnCode                                    LearnCodeOnline             LearnCodeCoursesCert YearsCode YearsCodePro                               DevType                   OrgSize                 PurchaseInfluence      TechList                                         BuyNewTool                       Country                   Currency     CompTotal                             LanguageHaveWorkedWith                             LanguageWantToWorkWith                             DatabaseHaveWorkedWith                             DatabaseWantToWorkWith                             PlatformHaveWorkedWith                             PlatformWantToWorkWith  \
# ResponseId
# ...

# %%
schema_df.iloc[5]
# Out:
# qname                                                MainBranch
# question      Which of the following options best describes ...
# force_resp                                                 True
# type                                                         MC
# selector                                                   SAVR
# Name: QID2, dtype: object

# %%
# to sort the index in alphabetic order then we can use
schema_df.sort_index()
# Out:
#                        qname                                           question force_resp    type selector
# qid
# QID1                      S1  <span style="font-size:22px; font-family: aria...      False      DB       TB
# QID100           SOVisitFreq  How frequently would you say you visit Stack O...      False      MC     SAVR
# QID101             SOAccount              Do you have a Stack Overflow account?      False      MC     SAVR
# QID102            SOPartFreq  How frequently would you say you participate i...      False      MC     SAVR
# QID106                SOComm  Do you consider yourself a member of the Stack...      False      MC     SAVR
# QID12               MetaInfo                                  Browser Meta Info      False    Meta  Browser
# QID127                   Age                                What is your age? *       True      MC     MAVR
# QID131                    S7  <span style="font-size:22px;"><strong>Final Qu...      False      DB       TB
# ...

# %%
# in here we're trying to fetch the data froms schema where id = QID1 and the column question so it will descibes the question for that particular id
schema_df.loc['QID1','question']
# Out:
# '<span style="font-size:22px; font-family: arial,helvetica,sans-serif; font-weight: 700;">Basic Information</span><br>\n<br>\n<p><span style="font-size:16px; font-family:arial,helvetica,sans-serif;">The first section will focus on some basic information about who you are.<br>\n<br>\nMost questions in this section are required. Required questions are noted with *.</span></p>'

# %%
df
# Out:
#                Q120                      MainBranch                 Age                                         Employment                            RemoteWork                                   CodingActivities                                            EdLevel                                          LearnCode                                    LearnCodeOnline             LearnCodeCoursesCert YearsCode YearsCodePro                               DevType                   OrgSize                 PurchaseInfluence      TechList                                         BuyNewTool                       Country                   Currency     CompTotal                             LanguageHaveWorkedWith                             LanguageWantToWorkWith                             DatabaseHaveWorkedWith                             DatabaseWantToWorkWith                             PlatformHaveWorkedWith                             PlatformWantToWorkWith  \
# ResponseId
# ...

# %%
schema_df
# Out:
#                        qname                                           question force_resp    type selector
# qid
# QID16                     S0  <div><span style="font-size:19px;"><strong>Hel...      False      DB       TB
# QID12               MetaInfo                                  Browser Meta Info      False    Meta  Browser
# QID310                  Q310  <div><span style="font-size:19px;"><strong>You...      False      DB       TB
# QID312                  Q120                                                          True      MC     SAVR
# QID1                      S1  <span style="font-size:22px; font-family: aria...      False      DB       TB
# QID2              MainBranch  Which of the following options best describes ...       True      MC     SAVR
# QID127                   Age                                What is your age? *       True      MC     MAVR
# QID296            Employment  Which of the following best describes your cur...      False      MC     MAVR
# ...

# %%
schema_df
# Out:
#                        qname                                           question force_resp    type selector
# qid
# QID16                     S0  <div><span style="font-size:19px;"><strong>Hel...      False      DB       TB
# QID12               MetaInfo                                  Browser Meta Info      False    Meta  Browser
# QID310                  Q310  <div><span style="font-size:19px;"><strong>You...      False      DB       TB
# QID312                  Q120                                                          True      MC     SAVR
# QID1                      S1  <span style="font-size:22px; font-family: aria...      False      DB       TB
# QID2              MainBranch  Which of the following options best describes ...       True      MC     SAVR
# QID127                   Age                                What is your age? *       True      MC     MAVR
# QID296            Employment  Which of the following best describes your cur...      False      MC     MAVR
# ...

# %%
schema_df.loc['QID34','question']
# Out:
# 'NOT including education, how many years have you coded professionally (as a part of your work)?'

# %%
pd_people
# Out:
#         city     first      last
# 0     kannur  muhammed      amil
# 1  bangalore    jaseem  muhammed
# 2    calicut      john   abraham
# 3   thrissur      dane        sd

# %% [markdown]
# # filtering

# %%
pd_people['first'] == ' muhammed'
# Out:
# city
# kannur       False
# bangalore    False
# calicut      False
# thrissur     False
# Name: first, dtype: bool

# %%
filter_pd = pd_people['last'] == 'amil'
pd_people.reset_index(inplace = True)

# %%
pd_people[filter_pd]
# Out:
#    index    city     first  last
# 0      0  kannur  muhammed  amil

# %%
# the another method to filer is using the loc method and if you want a particular column then
pd_people.loc[filter_pd,'city']
# Out:
# 0    kannur
# Name: city, dtype: object

# %%
# using AND and OR operator in filter
filter_pd = (pd_people['last'] == 'amil') & (pd_people['first'] == 'muhammed')

# %%
pd_people.loc[filter_pd]
pd_people.drop(columns ='index')
# Out:
#         city     first      last
# 0     kannur  muhammed      amil
# 1  bangalore    jaseem  muhammed
# 2    calicut      john   abraham
# 3   thrissur      dane        sd

# %%
# if you want the opposite of the filter then :
filter_pd = (pd_people['first'] == 'muhammed') | (pd_people['last']== 'sd')

# %%
# here we're getting the opposite of our fliter
pd_people[-filter_pd]
# Out:
#    index       city   first      last
# 1      1  bangalore  jaseem  muhammed
# 2      2    calicut    john   abraham

# %%
df
# Out:
#        ResponseId     Q120                      MainBranch                 Age                                         Employment                            RemoteWork                                   CodingActivities                                            EdLevel                                          LearnCode                                    LearnCodeOnline             LearnCodeCoursesCert YearsCode YearsCodePro                               DevType                   OrgSize                 PurchaseInfluence      TechList                                         BuyNewTool                       Country                   Currency     CompTotal                             LanguageHaveWorkedWith                             LanguageWantToWorkWith                             DatabaseHaveWorkedWith                             DatabaseWantToWorkWith                             PlatformHaveWorkedWith                             PlatformWantToWorkWith  \
# ...

# %%
# df.set_index('ResponseId',inplace =True)

# %%
schema_df
# Out:
#                        qname                                           question force_resp    type selector
# qid
# QID16                     S0  <div><span style="font-size:19px;"><strong>Hel...      False      DB       TB
# QID12               MetaInfo                                  Browser Meta Info      False    Meta  Browser
# QID310                  Q310  <div><span style="font-size:19px;"><strong>You...      False      DB       TB
# QID312                  Q120                                                          True      MC     SAVR
# QID1                      S1  <span style="font-size:22px; font-family: aria...      False      DB       TB
# QID2              MainBranch  Which of the following options best describes ...       True      MC     SAVR
# QID127                   Age                                What is your age? *       True      MC     MAVR
# QID296            Employment  Which of the following best describes your cur...      False      MC     MAVR
# ...

# %%
filter_df = (df['MainBranch'] == 'I am a developer by profession') | (df['MainBranch']=='I code primarily as a hobby')

# %%
df.loc[filter_df, ['MainBranch','Age', 'Employment','PlatformHaveWorkedWith']]
# Out:
#                            MainBranch                 Age                                         Employment                             PlatformHaveWorkedWith
# 1      I am a developer by profession     25-34 years old                                Employed, full-time           Amazon Web Services (AWS);Netlify;Vercel
# 2      I am a developer by profession     45-54 years old                                Employed, full-time  Amazon Web Services (AWS);Google Cloud;OpenSta...
# 3      I am a developer by profession     25-34 years old                                Employed, full-time                                  Cloudflare;Heroku
# 4      I am a developer by profession     25-34 years old  Employed, full-time;Independent contractor, fr...  Amazon Web Services (AWS);Firebase;Heroku;Netl...
# 5      I am a developer by profession     35-44 years old                                Employed, full-time  Amazon Web Services (AWS);Cloudflare;Google Cloud
# ...

# %%
df.columns
# Out:
# Index(['Q120', 'MainBranch', 'Age', 'Employment', 'RemoteWork',
#        'CodingActivities', 'EdLevel', 'LearnCode', 'LearnCodeOnline',
#        'LearnCodeCoursesCert', 'YearsCode', 'YearsCodePro', 'DevType',
#        'OrgSize', 'PurchaseInfluence', 'TechList', 'BuyNewTool', 'Country',
#        'Currency', 'CompTotal', 'LanguageHaveWorkedWith',
#        'LanguageWantToWorkWith', 'DatabaseHaveWorkedWith',
#        'DatabaseWantToWorkWith', 'PlatformHaveWorkedWith',
#        'PlatformWantToWorkWith', 'WebframeHaveWorkedWith',
#        'WebframeWantToWorkWith', 'MiscTechHaveWorkedWith',
#        'MiscTechWantToWorkWith', 'ToolsTechHaveWorkedWith',
#        'ToolsTechWantToWorkWith', 'NEWCollabToolsHaveWorkedWith',
#        'NEWCollabToolsWantToWorkWith', 'OpSysPersonal use',
#        'OpSysProfessional use', 'OfficeStackAsyncHaveWorkedWith',
#        'OfficeStackAsyncWantToWorkWith', 'OfficeStackSyncHaveWorkedWith',
#        'OfficeStackSyncWantToWorkWith', 'AISearchHaveWorkedWith',
# ...

# %%
column_name = 'question'

# Check if the column exists
if column_name in df.columns:
    print(f"'{column_name}' column exists in the DataFrame.")
else:
    print(f"'{column_name}' column does not exist in the DataFrame.")
# Out:
# 'question' column does not exist in the DataFrame.

# %%
print(schema_df.index)
# Out:
# Index(['QID16', 'QID12', 'QID310', 'QID312', 'QID1', 'QID2', 'QID127', 'QID296', 'QID308', 'QID297', 'QID190', 'QID25', 'QID276', 'QID281', 'QID306', 'QID32', 'QID34', 'QID31', 'QID29', 'QID278', 'QID322', 'QID279', 'QID6', 'QID50', 'QID51', 'QID61', 'QID233', 'QID262', 'QID263', 'QID264', 'QID265', 'QID275', 'QID274', 'QID71', 'QID282', 'QID307', 'QID327', 'QID328', 'QID91', 'QID266', 'QID100', 'QID101', 'QID102', 'QID106', 'QID313', 'QID325', 'QID314', 'QID315', 'QID324', 'QID316', 'QID319', 'QID320', 'QID321', 'QID295', 'QID299', 'QID287', 'QID288', 'QID289', 'QID290', 'QID291', 'QID292', 'QID304', 'QID326', 'QID286', 'QID131', 'QID132', 'QID133', 'QID289', 'QID289', 'QID289', 'QID289', 'QID289', 'QID289', 'QID289', 'QID289', 'QID290', 'QID290', 'QID290'], dtype='object', name='qid')

# %%
df.loc[0:5,'MainBranch']
# Out:
# 0                     None of these
# 1    I am a developer by profession
# 2    I am a developer by profession
# 3    I am a developer by profession
# 4    I am a developer by profession
# 5    I am a developer by profession
# Name: MainBranch, dtype: object

# %%
countries = [' United Stated', 'India','United Kingdom','Germany']

# %%
df_filter = (df['Country'].isin(countries))

# %%
df.loc[df_filter,'Country']
# Out:
# 9          India
# 15       Germany
# 19       Germany
# 21       Germany
# 23       Germany
#           ...
# 89132    Germany
# 89146    Germany
# 89164      India
# 89165      India
# 89167      India
# Name: Country, Length: 12953, dtype: object

# %%
df['LanguageHaveWorkedWith']
# Out:
# 0                                                      NaN
# 1                               HTML/CSS;JavaScript;Python
# 2                               Bash/Shell (all shells);Go
# 3        Bash/Shell (all shells);HTML/CSS;JavaScript;PH...
# 4                           HTML/CSS;JavaScript;TypeScript
#                                ...
# 89179              HTML/CSS;Java;JavaScript;SQL;TypeScript
# 89180                                 Dart;Java;Python;SQL
# 89181    Assembly;Bash/Shell (all shells);C;C#;Python;R...
# 89182    Bash/Shell (all shells);C#;HTML/CSS;Java;JavaS...
# 89183                      C#;Go;JavaScript;SQL;TypeScript
# Name: LanguageHaveWorkedWith, Length: 89184, dtype: object

# %%
filt = df['LanguageHaveWorkedWith'].str.contains('Python', na= False)

# %%
df.loc[filt,'LanguageHaveWorkedWith']
# Out:
# 1                               HTML/CSS;JavaScript;Python
# 7        Go;HTML/CSS;JavaScript;Python;Rust;SQL;TypeScript
# 9           HTML/CSS;Java;JavaScript;Python;SQL;TypeScript
# 10                       C#;C++;HTML/CSS;JavaScript;Python
# 11       C#;HTML/CSS;JavaScript;Kotlin;PowerShell;Pytho...
#                                ...
# 89172    Bash/Shell (all shells);HTML/CSS;JavaScript;Pe...
# 89176    HTML/CSS;Java;JavaScript;PHP;Python;SQL;TypeSc...
# 89180                                 Dart;Java;Python;SQL
# 89181    Assembly;Bash/Shell (all shells);C;C#;Python;R...
# 89182    Bash/Shell (all shells);C#;HTML/CSS;Java;JavaS...
# Name: LanguageHaveWorkedWith, Length: 43158, dtype: object

# %% [markdown]
# # Updating rows and columns

# %%
pd_people
pd_people.drop(columns = 'index', inplace = True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[92], line 2
#       1 pd_people
# ----> 2 pd_people.drop(columns = 'index', inplace = True)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:5344, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5196 def drop(
#    5197     self,
#    5198     labels: IndexLabel | None = None,
#    (...)
#    5205     errors: IgnoreRaise = "raise",
#    5206 ) -> DataFrame | None:
#    5207     """
#    5208     Drop specified labels from rows or columns.
#    5209
#    (...)
#    5342             weight  1.0     0.8
#    5343     """
# -> 5344     return super().drop(
#    5345         labels=labels,
#    5346         axis=axis,
#    5347         index=index,
#    5348         columns=columns,
#    5349         level=level,
#    5350         inplace=inplace,
#    5351         errors=errors,
# ...

# %%
# some basic way to update the columns
pd_people.columns = ['first_name','last_name','city']

# %%
pd_people.columns
# Out:
# Index(['first_name', 'last_name', 'city'], dtype='object')

# %%
pd_people.columns = [x.lower() for x in pd_people.columns]

# %%
pd_people
# Out:
#   first_name last_name      city
# 0     kannur  muhammed      amil
# 1  bangalore    jaseem  muhammed
# 2    calicut      john   abraham
# 3   thrissur      dane        sd

# %%
pd_people.columns.str.replace('_', '   ')
pd_people
# Out:
#   first_name last_name      city
# 0     kannur  muhammed      amil
# 1  bangalore    jaseem  muhammed
# 2    calicut      john   abraham
# 3   thrissur      dane        sd

# %%
### updating the columns using rename method 
pd_people.rename(columns = {'first_name': 'first','last_name':'last'}, inplace = True)
pd_people.columns
# Out:
# Index(['first', 'last', 'city'], dtype='object')

# %%
filter_people = (pd_people['first'] == 'kannur') & (pd_people['last']== 'muhammed' )

# %%
pd_people[filter_people]
# Out:
#     first      last  city
# 0  kannur  muhammed  amil

# %%
# updating the row
pd_people[filter_people] = ['pranav','padmu','kannur']

# %%
pd_people
# Out:
#        first    last      city
# 0     pranav   padmu    kannur
# 1  bangalore  jaseem  muhammed
# 2    calicut    john   abraham
# 3   thrissur    dane        sd

# %%
pd_people.loc[1, ['first','city','last']] = ['jaseel','kasargode','abdulla']

# %%
pd_people.loc[3, ['first','city','last']] = ['alen','thrissur','jose']
pd_people.loc[2, ['first','city']] = ['affef','malappuram']

# %%
pd_people
# Out:
#     first     last        city
# 0  pranav    padmu      kannur
# 1  jaseel  abdulla   kasargode
# 2   affef     john  malappuram
# 3    alen     jose    thrissur

# %%
# another way to update the row
pd_people.loc[2, ['first','city']]= ['amillll','thalassery']

# %%
pd_people
# Out:
#       first    last        city
# 0    pranav   padmu      kannur
# 1    jaseel  jaseem   kasargode
# 2   amillll    john  thalassery
# 3  thrissur    dane          sd

# %%
pd_people.loc[3,['first','last']]= ['basil','benny']

# %%
pd_people
# Out:
#      first    last        city
# 0   pranav   padmu      kannur
# 1   jaseel  jaseem   kasargode
# 2  amillll    john  thalassery
# 3    basil   benny          sd

# %%
# update multiple row

pd_people['first'] = pd_people['first'].str.lower()

# %%
pd_people
# Out:
#     first     last        city
# 0  pranav    padmu      kannur
# 1  jaseel  abdulla   kasargode
# 2   affef     john  malappuram
# 3    alen     jose    thrissur

# %%
def update_city(city):
    return city.upper()

# %%
#The apply method allows you to apply a function along an axis of the DataFrame or Series.
#For DataFrames:
#Apply a function along rows or columns.
#or Series:
#Apply a function element-wise
pd_people['city'].apply(update_city)
# Out:
# 0        KANNUR
# 1     KASARGODE
# 2    MALAPPURAM
# 3      THRISSUR
# Name: city, dtype: object

# %%
pd_people
# Out:
#     first     last        city
# 0  pranav    padmu      kannur
# 1  jaseel  abdulla   kasargode
# 2   affef     john  malappuram
# 3    alen     jose    thrissur

# %%
pd_people['city'] = pd_people['city'].apply(update_city)

# %%
pd_people
# Out:
#     first     last        city
# 0  pranav    padmu      KANNUR
# 1  jaseel  abdulla   KASARGODE
# 2   affef     john  MALAPPURAM
# 3    alen     jose    THRISSUR

# %%
 pd_people['city'] = pd_people['city'].apply(lambda x : x.upper())

# %%
pd_people.loc[0,'first'] = 'amil'

# %%
filt = pd_people['city'] == 'KANNUR'

pd_people.loc[filt,['first','last','city']] = ['Muhammed','Amil', 'kannur']
pd_people
# Out:
#       first     last        city
# 0  Muhammed     Amil      kannur
# 1    jaseel  abdulla   KASARGODE
# 2     affef     john  MALAPPURAM
# 3      alen     jose    THRISSUR

# %%
pd_people
df.apply(len)
# Out:
# Q120                   89184
# MainBranch             89184
# Age                    89184
# Employment             89184
# RemoteWork             89184
#                        ...
# ProfessionalTech       89184
# Industry               89184
# SurveyLength           89184
# SurveyEase             89184
# ConvertedCompYearly    89184
# Length: 83, dtype: int64

# %%
df
# Out:
#                Q120                      MainBranch                 Age  \
# ResponseId
# 1           I agree                   None of these     18-24 years old
# 2           I agree  I am a developer by profession     25-34 years old
# 3           I agree  I am a developer by profession     45-54 years old
# 4           I agree  I am a developer by profession     25-34 years old
# 5           I agree  I am a developer by profession     25-34 years old
# ...             ...                             ...                 ...
# 89180       I agree  I am a developer by profession     25-34 years old
# 89181       I agree  I am a developer by profession     18-24 years old
# 89182       I agree     I code primarily as a hobby   Prefer not to say
# 89183       I agree  I am a developer by profession  Under 18 years old
# 89184       I agree  I am a developer by profession     35-44 years old
#
#                                                    Employment  \
# ResponseId
# ...

# %%
len(df['Age'])
# Out:
# 89184

# %%
df.apply(len, axis = 'columns')
# Out:
# 0        84
# 1        84
# 2        84
# 3        84
# 4        84
#          ..
# 89179    84
# 89180    84
# 89181    84
# 89182    84
# 89183    84
# Length: 89184, dtype: int64

# %%
pd_people.apply(pd.Series.min)
# Out:
# first     Muhammed
# last          Amil
# city     KASARGODE
# dtype: object

# %%
pd_people.apply(pd.Series.max)
# Out:
# first    jaseel
# last       jose
# city     kannur
# dtype: object

# %%
#The applymap method applies a function element-wise across the entire DataFrame. It is useful for applying a function to each element of a DataFrame.
pd_people.applymap(len)
# Out:
# C:\Users\amil\AppData\Local\Temp\ipykernel_19388\3814902137.py:2: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   pd_people.applymap(len)
#    first  last  city
# 0      8     4     6
# 1      6     7     9
# 2      5     4    10
# 3      4     4     8

# %%
pd_people = pd_people.applymap(lambda x : x.upper()) 
pd_people
# Out:
# C:\Users\amil\AppData\Local\Temp\ipykernel_15632\3592792881.py:1: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   pd_people = pd_people.applymap(lambda x : x.upper())
#      first    last        city
# 0     AMIL   PADMU      KANNUR
# 1   JASEEL  JASEEM   KASARGODE
# 2  AMILLLL    JOHN  THALASSERY
# 3    BASIL   BENNY          SD

# %%
# used to map values in a Series according to an input correspondence (e.g., dictionary, function).
pd_people['first']= pd_people['first'].map(lambda x:x.lower())

# %%
pd_people
# Out:
#       first     last        city
# 0  muhammed     Amil      kannur
# 1    jaseel  abdulla   KASARGODE
# 2     affef     john  MALAPPURAM
# 3      alen     jose    THRISSUR

# %%
# when you don't want to apply the changes for each value then we can use replace otherwise here in the below example you can see the Nan values it's because we're not changeing that specific value 
pd_people['city'].map({'iritty': 'jkk','bangalore':'mangalore','thalassery':'malappuram','THRISSUR':'sgpalaya'})
# Out:
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# Name: city, dtype: object

# %%
# used to replace values in a Series or DataFrame according to specified values, list, dictionary, or regular expression.
pd_people['city'].replace({'kannur': 'iritty',' kasargode':'mmangalore','calicut':'thalassery','thrissur':'idukki'},inplace = True)

# %%
pd_people['city']= pd_people['city'].apply(lambda x:x.lower())

# %%
pd_people
# Out:
#       first     last        city
# 0  muhammed     Amil      iritty
# 1    jaseel  abdulla   kasargode
# 2     affef     john  malappuram
# 3      alen     jose      idukki

# %%
df.rename(columns = {'LanguageHaveWorkedWith': 'LanguageYouWorkedWith'})
# Out:
#        ResponseId     Q120                      MainBranch                 Age                                         Employment                            RemoteWork                                   CodingActivities                                            EdLevel                                          LearnCode                                    LearnCodeOnline             LearnCodeCoursesCert YearsCode YearsCodePro                               DevType                   OrgSize                 PurchaseInfluence      TechList                                         BuyNewTool                       Country                   Currency     CompTotal                              LanguageYouWorkedWith                             LanguageWantToWorkWith                             DatabaseHaveWorkedWith                             DatabaseWantToWorkWith                             PlatformHaveWorkedWith                             PlatformWantToWorkWith  \
# ...

# %%
df.loc[120:180,['Q120']]
# Out:
#         Q120
# 120  I agree
# 121  I agree
# 122  I agree
# 123  I agree
# 124  I agree
# 125  I agree
# 126  I agree
# 127  I agree
# 128  I agree
# 129  I agree
# 130  I agree
# 131  I agree
# 132  I agree
# 133  I agree
# 134  I agree
# 135  I agree
# 136  I agree
# 137  I agree
# 138  I agree
# 139  I agree
# 140  I agree
# 141  I agree
# 142  I agree
# 143  I agree
# 144  I agree
# 145  I agree
# 146  I agree
# 147  I agree
# 148  I agree
# 149  I agree
# 150  I agree
# 151  I agree
# 152  I agree
# 153  I agree
# 154  I agree
# 155  I agree
# 156  I agree
# 157  I agree
# 158  I agree
# 159  I agree
# 160  I agree
# 161  I agree
# 162  I agree
# 163  I agree
# 164  I agree
# 165  I agree
# 166  I agree
# 167  I agree
# 168  I agree
# 169  I agree
# 170  I agree
# 171  I agree
# 172  I agree
# 173  I agree
# 174  I agree
# 175  I agree
# 176  I agree
# 177  I agree
# 178  I agree
# 179  I agree
# 180  I agree

# %%
df['Q120'].map({'I agree': True})
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#          ...
# 89179    True
# 89180    True
# 89181    True
# 89182    True
# 89183    True
# Name: Q120, Length: 89184, dtype: bool

# %% [markdown]
# # add or remove rows and columns

# %%
pd_people['first'] + ' ' + pd_people['last']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'first'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[273], line 1
# ----> 1 pd_people['first'] + ' ' + pd_people['last']
#
# ...

# %%
pd_people =  pd_people.map(lambda x :x.lower())

# %%
pd_people
# Out:
#   first_name last_name age
# 0       john       doe  33
# 1       jane   unknown  23
# 2    missing     smith  22
# 3      alice     brown  43

# %%
pd_people['full_name'] = pd_people['first_name'] + ' ' + pd_people['last_name']

# %%
pd_people
# Out:
#   first_name last_name age      full_name
# 0       john       doe  33       john doe
# 1       jane   unknown  23   jane unknown
# 2    missing     smith  22  missing smith
# 3      alice     brown  43    alice brown

# %%
# adding column using a apply
pd_people['new_city'] = pd_people['city'].apply(lambda x:x.upper())
pd_people
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'city'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[285], line 2
#       1 # adding column using a apply
# ...

# %%
filt = pd_people['city']=='irritty'
print(filt)
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# Name: city, dtype: bool

# %%
pd_people.loc[filt,'city'] = 'idukki'

# %%
pd_people.rename(columns={"(True, 'new_city')": 'correct_name'}, inplace=True)

# %%
pd_people.columns
# Out:
# Index(['first', 'last', 'city', 'full_name', 'new_city', True,
#        (True, 'new_city')],
#       dtype='object')

# %%
 pd_people.drop(columns = 'new_city')
# Out:
#       first     last        city       full_name
# 0  muhammed     amil      iritty   muhammed amil
# 1    jaseel  abdulla   kasargode  jaseel abdulla
# 2     affef     john  malappuram      affef john
# 3      alen     jose      idukki       alen jose

# %%
# pd_people.drop(columns = ['new_city'])
# Out:
#      first    last        city      full_name True (True, new_city)
# 0     amil   padmu      kannur     amil padmu   tt               tt
# 1   jaseel  jaseem   kasargode  jaseel jaseem   tt               tt
# 2  amillll    john  thalassery   amillll john   tt               tt
# 3    basil   benny   kasargode    basil benny   tt               tt

# %%
pd_people.columns
# Out:
# Index(['first', 'last', 'city', 'full_name', 'new_city'], dtype='object')

# %%
pd_people
# Out:
#       first     last        city       full_name    new_city
# 0  muhammed     amil      iritty   muhammed amil      IRITTY
# 1    jaseel  abdulla   kasargode  jaseel abdulla   KASARGODE
# 2     affef     john  malappuram      affef john  MALAPPURAM
# 3      alen     jose      idukki       alen jose      IDUKKI

# %%
pd_people['full_name'] = pd_people['first'] + ' ' + pd_people['last']

# %%
# pd_people.drop( columns = ['full_name','new_city'], inplace = True)

# %%
pd_people
# Out:
#       first     last        city       full_name    new_city
# 0  muhammed     amil      iritty   muhammed amil      IRITTY
# 1    jaseel  abdulla   kasargode  jaseel abdulla   KASARGODE
# 2     affef     john  malappuram      affef john  MALAPPURAM
# 3      alen     jose      idukki       alen jose      IDUKKI

# %%
# to undo the operations that done above:
pd_people['full_name'].str.split(' ',expand = True)
# Out:
#           0        1
# 0  muhammed     amil
# 1    jaseel  abdulla
# 2     affef     john
# 3      alen     jose

# %%
pd_people[['first_','last_']] = pd_people['full_name'].str.split('   ', expand = True)

# %%
pd_people
# Out:
#       first     last        city       full_name    new_city    first_    last_
# 0  muhammed     amil      iritty   muhammed amil      IRITTY  muhammed     amil
# 1    jaseel  abdulla   kasargode  jaseel abdulla   KASARGODE    jaseel  abdulla
# 2     affef     john  malappuram      affef john  MALAPPURAM     affef     john
# 3      alen     jose      idukki       alen jose      IDUKKI      alen     jose

# %% [markdown]
# # adding and removing the rows

# %%
new_row = pd.DataFrame([{'first':'tony','last':'smoothy','city': 'nyc'}])
pd_people = pd.concat([pd_people, new_row], ignore_index = True)

# %%
pd_people
# Out:
#       first     last        city       full_name    new_city    first_    last_
# 0  muhammed     amil      iritty   muhammed amil      IRITTY  muhammed     amil
# 1    jaseel  abdulla   kasargode  jaseel abdulla   KASARGODE    jaseel  abdulla
# 2     affef     john  malappuram      affef john  MALAPPURAM     affef     john
# 3      alen     jose      idukki       alen jose      IDUKKI      alen     jose
# 4      tony  smoothy         nyc             NaN         NaN       NaN      NaN

# %%
people ={
    'first' :['captain','devil','batman'],
    'last':['america','jose','amalus'],
    'city':['america','thoppumpady','wayanad'],
}

# %%
pd_people2 = pd.DataFrame(people)

# %%
pd_people = pd.concat([pd_people,pd_people2], ignore_index = True)

# %%
pd_people
# Out:
#       first     last         city       full_name    new_city    first_    last_
# 0  muhammed     amil       iritty   muhammed amil      IRITTY  muhammed     amil
# 1    jaseel  abdulla    kasargode  jaseel abdulla   KASARGODE    jaseel  abdulla
# 2     affef     john   malappuram      affef john  MALAPPURAM     affef     john
# 3      alen     jose       idukki       alen jose      IDUKKI      alen     jose
# 4   captain  america      america             NaN         NaN       NaN      NaN
# 5     devil     jose  thoppumpady             NaN         NaN       NaN      NaN
# 6    batman   amalus      wayanad             NaN         NaN       NaN      NaN

# %%
pd_people.drop(index =[0,2,4], inplace = True)

# %%
# using conditions
#pd_people.drop(index = pd_people[pd_people['last']== 'amalus'].index)
filt = pd_people['last'] == 'benny'
pd_people.drop(index = pd_people[filt].index)
# Out:
#      first     last         city      full_name   new_city first___ last___
# 1   JASEEL   jaseem    kasargode  JASEEL jaseem  kasargode   JASEEL  jaseem
# 5  captain  america      america            NaN        NaN      NaN     NaN
# 6    devil     jose  thoppumpady            NaN        NaN      NaN     NaN
# 7   batman   amalus      wayanad            NaN        NaN      NaN     NaN

# %%
filt = pd.isna(pd_people['full_name'])
pd_people = pd_people.drop(index = pd_people[filt].index)
pd_people
# Out:
#       first     last        city       full_name    new_city    first_    last_
# 0  muhammed     amil      iritty   muhammed amil      IRITTY  muhammed     amil
# 1    jaseel  abdulla   kasargode  jaseel abdulla   KASARGODE    jaseel  abdulla
# 2     affef     john  malappuram      affef john  MALAPPURAM     affef     john
# 3      alen     jose      idukki       alen jose      IDUKKI      alen     jose

# %% [markdown]
# # sorting

# %%
pd_people
# Out:
#       first     last         city       full_name    new_city    first_    last_
# 0  muhammed     amil       iritty   muhammed amil      IRITTY  muhammed     amil
# 1    jaseel  abdulla    kasargode  jaseel abdulla   KASARGODE    jaseel  abdulla
# 2     affef     john   malappuram      affef john  MALAPPURAM     affef     john
# 3      alen     jose       idukki       alen jose      IDUKKI      alen     jose
# 4   captain  america      america             NaN         NaN       NaN      NaN
# 5     devil     jose  thoppumpady             NaN         NaN       NaN      NaN
# 6    batman   amalus      wayanad             NaN         NaN       NaN      NaN

# %%
pd_people.sort_values(by = 'last')
# Out:
#       first     last         city       full_name    new_city    first_    last_
# 1    jaseel  abdulla    kasargode  jaseel abdulla   KASARGODE    jaseel  abdulla
# 6    batman   amalus      wayanad             NaN         NaN       NaN      NaN
# 4   captain  america      america             NaN         NaN       NaN      NaN
# 0  muhammed     amil       iritty   muhammed amil      IRITTY  muhammed     amil
# 2     affef     john   malappuram      affef john  MALAPPURAM     affef     john
# 3      alen     jose       idukki       alen jose      IDUKKI      alen     jose
# 5     devil     jose  thoppumpady             NaN         NaN       NaN      NaN

# %%
pd_people.sort_values(by =['last','first'],ascending = False )
# Out:
#       first     last         city       full_name    new_city    first_    last_
# 5     devil     jose  thoppumpady             NaN         NaN       NaN      NaN
# 3      alen     jose       idukki       alen jose      IDUKKI      alen     jose
# 2     affef     john   malappuram      affef john  MALAPPURAM     affef     john
# 0  muhammed     amil       iritty   muhammed amil      IRITTY  muhammed     amil
# 4   captain  america      america             NaN         NaN       NaN      NaN
# 6    batman   amalus      wayanad             NaN         NaN       NaN      NaN
# 1    jaseel  abdulla    kasargode  jaseel abdulla   KASARGODE    jaseel  abdulla

# %%
new_row = pd.DataFrame([{'first':'adhil','last':'kvl','city':'malappuram'}])

# %%
pd_people = pd.concat([pd_people,new_row], ignore_index = True)

# %%
pd_people
# Out:
#       first     last         city       full_name    new_city    first_    last_
# 0  muhammed     amil       iritty   muhammed amil      IRITTY  muhammed     amil
# 1    jaseel  abdulla    kasargode  jaseel abdulla   KASARGODE    jaseel  abdulla
# 2     affef     john   malappuram      affef john  MALAPPURAM     affef     john
# 3      alen     jose       idukki       alen jose      IDUKKI      alen     jose
# 4   captain  america      america             NaN         NaN       NaN      NaN
# 5     devil     jose  thoppumpady             NaN         NaN       NaN      NaN
# 6    batman   amalus      wayanad             NaN         NaN       NaN      NaN
# 7     adhil      kvl   malappuram             NaN         NaN       NaN      NaN

# %%
new_row = pd.DataFrame([{'first':'baker','last':'kvl','city':'malappuram'}])

# %%
pd_people = pd.concat([pd_people,new_row], ignore_index = True)

# %%
# so here passing true and false because we want the first columns as descending and second column first in ascending
pd_people = pd_people.sort_values(by =['last','first'],ascending = [False,True])
pd_people
# Out:
#       first     last         city       full_name    new_city    first_    last_
# 7     adhil      kvl   malappuram             NaN         NaN       NaN      NaN
# 8     baker      kvl   malappuram             NaN         NaN       NaN      NaN
# 3      alen     jose       idukki       alen jose      IDUKKI      alen     jose
# 5     devil     jose  thoppumpady             NaN         NaN       NaN      NaN
# 2     affef     john   malappuram      affef john  MALAPPURAM     affef     john
# 0  muhammed     amil       iritty   muhammed amil      IRITTY  muhammed     amil
# 4   captain  america      america             NaN         NaN       NaN      NaN
# 6    batman   amalus      wayanad             NaN         NaN       NaN      NaN
# 1    jaseel  abdulla    kasargode  jaseel abdulla   KASARGODE    jaseel  abdulla

# %%
pd_people
# Out:
#       first     last         city       full_name    new_city    first_    last_
# 7     adhil      kvl   malappuram             NaN         NaN       NaN      NaN
# 8     baker      kvl   malappuram             NaN         NaN       NaN      NaN
# 3      alen     jose       idukki       alen jose      IDUKKI      alen     jose
# 5     devil     jose  thoppumpady             NaN         NaN       NaN      NaN
# 2     affef     john   malappuram      affef john  MALAPPURAM     affef     john
# 0  muhammed     amil       iritty   muhammed amil      IRITTY  muhammed     amil
# 4   captain  america      america             NaN         NaN       NaN      NaN
# 6    batman   amalus      wayanad             NaN         NaN       NaN      NaN
# 1    jaseel  abdulla    kasargode  jaseel abdulla   KASARGODE    jaseel  abdulla

# %%
pd_people.sort_index()
# Out:
#       first     last         city       full_name    new_city    first_    last_
# 0  muhammed     amil       iritty   muhammed amil      IRITTY  muhammed     amil
# 1    jaseel  abdulla    kasargode  jaseel abdulla   KASARGODE    jaseel  abdulla
# 2     affef     john   malappuram      affef john  MALAPPURAM     affef     john
# 3      alen     jose       idukki       alen jose      IDUKKI      alen     jose
# 4   captain  america      america             NaN         NaN       NaN      NaN
# 5     devil     jose  thoppumpady             NaN         NaN       NaN      NaN
# 6    batman   amalus      wayanad             NaN         NaN       NaN      NaN
# 7     adhil      kvl   malappuram             NaN         NaN       NaN      NaN
# 8     baker      kvl   malappuram             NaN         NaN       NaN      NaN

# %%
pd_people['city'].sort_values()
# Out:
# 4        america
# 3         idukki
# 0         iritty
# 1      kasargode
# 7     malappuram
# 8     malappuram
# 2     malappuram
# 5    thoppumpady
# 6        wayanad
# Name: city, dtype: object

# %%
df.sort_values(by = 'Country', inplace = True)
df
# Out:
#        ResponseId     Q120                                         MainBranch                Age                                         Employment RemoteWork                                   CodingActivities                                            EdLevel                                          LearnCode                                    LearnCodeOnline             LearnCodeCoursesCert           YearsCode YearsCodePro                DevType                                            OrgSize                 PurchaseInfluence      TechList                                         BuyNewTool      Country            Currency  CompTotal                             LanguageHaveWorkedWith           LanguageWantToWorkWith                            DatabaseHaveWorkedWith                             DatabaseWantToWorkWith         PlatformHaveWorkedWith                             PlatformWantToWorkWith               WebframeHaveWorkedWith              WebframeWantToWorkWith  \
# ...

# %%
df[['Country','CompTotal']]
# Out:
#            Country  CompTotal
# 21497  Afghanistan        NaN
# 61079  Afghanistan        NaN
# 26531  Afghanistan        NaN
# 31396  Afghanistan        NaN
# 75451  Afghanistan        NaN
# ...            ...        ...
# 88820          NaN        NaN
# 88828          NaN        NaN
# 88830          NaN        NaN
# 89028          NaN        NaN
# 89159          NaN        NaN
#
# [89184 rows x 2 columns]

# %%
df.sort_values(by = ['Country','CompTotal'],ascending = [True, False] )
# Out:
#        ResponseId     Q120                      MainBranch                Age           Employment                            RemoteWork                                   CodingActivities                                            EdLevel                                          LearnCode                                    LearnCodeOnline LearnCodeCoursesCert YearsCode YearsCodePro                DevType             OrgSize                 PurchaseInfluence      TechList                                         BuyNewTool      Country             Currency    CompTotal                             LanguageHaveWorkedWith                         LanguageWantToWorkWith                             DatabaseHaveWorkedWith                             DatabaseWantToWorkWith     PlatformHaveWorkedWith                         PlatformWantToWorkWith                             WebframeHaveWorkedWith                        WebframeWantToWorkWith          MiscTechHaveWorkedWith  \
# ...

# %%
df
# Out:
#                Q120                      MainBranch                 Age                                         Employment                            RemoteWork                                   CodingActivities                                            EdLevel                                          LearnCode                                    LearnCodeOnline LearnCodeCoursesCert YearsCode YearsCodePro                                        DevType                                            OrgSize                 PurchaseInfluence      TechList                                         BuyNewTool      Country                         Currency  CompTotal                         LanguageHaveWorkedWith               LanguageWantToWorkWith                 DatabaseHaveWorkedWith      DatabaseWantToWorkWith              PlatformHaveWorkedWith                         PlatformWantToWorkWith       WebframeHaveWorkedWith WebframeWantToWorkWith MiscTechHaveWorkedWith  \
# ResponseId
# ...

# %%
# to get the first n largest 
df['CompTotal'].nlargest(10)
# Out:
# ResponseId
# 56323    5.000000e+46
# 18464    1.000000e+21
# 43557    1.000000e+16
# 49554    1.000000e+16
# 35780    1.000000e+15
# 15440    4.567887e+12
# 33079    1.000000e+11
# 19680    2.239672e+10
# 56854    1.980000e+10
# 9176     1.840199e+10
# Name: CompTotal, dtype: float64

# %%
df['CompTotal'].nlargest(10)
# Out:
# 56322    5.000000e+46
# 18463    1.000000e+21
# 43556    1.000000e+16
# 49553    1.000000e+16
# 35779    1.000000e+15
# 15439    4.567887e+12
# 33078    1.000000e+11
# 19679    2.239672e+10
# 56853    1.980000e+10
# 9175     1.840199e+10
# Name: CompTotal, dtype: float64

# %% [markdown]
# # Grouping and Aggregating

# %%
df
# Out:
#                Q120                      MainBranch                 Age                                         Employment                            RemoteWork                                   CodingActivities                                            EdLevel                                          LearnCode                                    LearnCodeOnline LearnCodeCoursesCert YearsCode YearsCodePro                                        DevType                                            OrgSize                 PurchaseInfluence      TechList                                         BuyNewTool      Country                         Currency  CompTotal                         LanguageHaveWorkedWith               LanguageWantToWorkWith                 DatabaseHaveWorkedWith      DatabaseWantToWorkWith              PlatformHaveWorkedWith                         PlatformWantToWorkWith       WebframeHaveWorkedWith WebframeWantToWorkWith MiscTechHaveWorkedWith  \
# ResponseId
# ...

# %%
df['CompTotal'].head(10)
# Out:
# 21497         NaN
# 61079         NaN
# 26531         NaN
# 31396         NaN
# 75451         NaN
# 39318         NaN
# 17872    100000.0
# 57686         NaN
# 23094         NaN
# 27884         NaN
# Name: CompTotal, dtype: float64

# %%
df['CompTotal'].median()
pd.set_option('display.min_rows', 10)

# %%
df['CompTotal'] = df['CompTotal'].astype(float)
df['CompTotal'].median()
# Out:
# 115000.0

# %%
pd.set_option('display.min_rows', 10)

# %%
df.describe()
# Out:
#           YearsCode     CompTotal       WorkExp  ConvertedCompYearly
# count  87435.000000  4.822500e+04  43579.000000         4.801900e+04
# mean      13.966855  1.036807e+42     11.405126         1.031101e+05
# std       10.552950  2.276847e+44      9.051989         6.814188e+05
# min        0.000000  0.000000e+00      0.000000         1.000000e+00
# 25%        6.000000  6.300000e+04      5.000000         4.390700e+04
# 50%       11.000000  1.150000e+05      9.000000         7.496300e+04
# 75%       20.000000  2.300000e+05     16.000000         1.216410e+05
# max       51.000000  5.000000e+46     50.000000         7.435143e+07

# %%
df['Age'].value_counts(normalize = True)
# Out:
# Age
# 25-34 years old       0.372791
# 35-44 years old       0.230221
# 18-24 years old       0.201056
# 45-54 years old       0.093447
# Under 18 years old    0.046286
# 55-64 years old       0.038034
# 65 years or older     0.013130
# Prefer not to say     0.005035
# Name: proportion, dtype: float64

# %%
df['Age'].count()
# Out:
# 89184

# %%
df['Age'].value_counts()
# Out:
# Age
# 25-34 years old       33247
# 35-44 years old       20532
# 18-24 years old       17931
# 45-54 years old        8334
# Under 18 years old     4128
# 55-64 years old        3392
# 65 years or older      1171
# Prefer not to say       449
# Name: count, dtype: int64

# %%
df['Country'].value_counts()
# Out:
# Country
# United States of America                                18647
# Germany                                                  7328
# India                                                    5625
# United Kingdom of Great Britain and Northern Ireland     5552
# Canada                                                   3507
#                                                         ...
# Grenada                                                     1
# Guinea-Bissau                                               1
# Liechtenstein                                               1
# Marshall Islands                                            1
# Saint Kitts and Nevis                                       1
# Name: count, Length: 185, dtype: int64

# %%
# in groupby function involves splitting the object ,applying the function , cobining the result
country_grp = df.groupby(['Country'])

# %%
country_grp.get_group('United States of America')
# Out:
#        ResponseId     Q120                                         MainBranch                 Age                                         Employment                            RemoteWork                                   CodingActivities                                            EdLevel                                          LearnCode                                    LearnCodeOnline       LearnCodeCoursesCert YearsCode YearsCodePro                                        DevType                                            OrgSize              PurchaseInfluence     TechList                                         BuyNewTool                   Country                   Currency  CompTotal                             LanguageHaveWorkedWith                             LanguageWantToWorkWith                   DatabaseHaveWorkedWith                     DatabaseWantToWorkWith                         PlatformHaveWorkedWith                             PlatformWantToWorkWith  \
# ...

# %%
filt = df['Country']== 'United States of America'
df.loc[filt,'Age'].value_counts()
# Out:
# Age
# 25-34 years old       6283
# 35-44 years old       4855
# 18-24 years old       2468
# 45-54 years old       2277
# 55-64 years old       1238
# Under 18 years old     867
# 65 years or older      529
# Prefer not to say      130
# Name: count, dtype: int64

# %%
country_grp[['Age','Employment']].value_counts().head(10)
# Out:
# Country      Age                 Employment
# Afghanistan  18-24 years old     Employed, full-time                                     8
#              25-34 years old     Employed, full-time                                     7
#              Under 18 years old  Student, full-time                                      3
#              25-34 years old     Not employed, but looking for work                      3
#              35-44 years old     Independent contractor, freelancer, or self-employed    3
#              55-64 years old     Independent contractor, freelancer, or self-employed    3
#              35-44 years old     Employed, full-time                                     3
#              Under 18 years old  Employed, full-time                                     2
#              Prefer not to say   I prefer not to say                                     2
#              18-24 years old     I prefer not to say                                     2
# ...

# %%
# its a method we can see a particular country                    
country_grp['Age'].value_counts(normalize = True).loc[['United States of America','India']]
# Out:
# Country                   Age
# United States of America  25-34 years old       0.336944
#                           35-44 years old       0.260364
#                           18-24 years old       0.132354
#                           45-54 years old       0.122111
#                           55-64 years old       0.066391
#                           Under 18 years old    0.046495
#                           65 years or older     0.028369
#                           Prefer not to say     0.006972
# India                     18-24 years old       0.408178
#                           25-34 years old       0.406933
#                           35-44 years old       0.091022
#                           Under 18 years old    0.067200
#                           45-54 years old       0.019022
#                           55-64 years old       0.003556
#                           Prefer not to say     0.003378
#                           65 years or older     0.000711
# ...

# %%
country_grp['CompTotal'].median().loc['India']
# Out:
# 1450000.0

# %%
country_grp['CompTotal'].agg(['mean','median'])
country_grp['CompTotal'].agg(['mean','median']).loc['India']
# Out:
#                                               mean       median
# Country
# Afghanistan                           6.666117e+07      62333.0
# Albania                               1.185178e+06     104850.0
# Algeria                               7.836667e+05     540000.0
# Andorra                               1.562473e+09     120000.0
# Angola                                2.600000e+06    2600000.0
# ...                                            ...          ...
# Venezuela, Bolivarian Republic of...  2.482463e+04      14400.0
# Viet Nam                              3.287808e+08  200000000.0
# Yemen                                 2.252071e+06       9000.0
# Zambia                                1.507400e+05      84000.0
# Zimbabwe                              2.674000e+04      12500.0
#
# [185 rows x 2 columns]

# %%
# using normal filter method to find who use python
filt = df['Country'] == 'United States of America'

# %%
df.loc[filt,'LanguageHaveWorkedWith'].str.contains('Python').sum()
# Out:
# 10062

# %%
#country_grp['LanguageHaveWorkedWith'].str.contains('Python').sum()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[139], line 1
# ----> 1 country_grp['LanguageHaveWorkedWith'].str.contains('Python').sum()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\groupby.py:1312, in GroupBy.__getattr__(self, attr)
#    1309 if attr in self.obj:
#    1310     return self[attr]
# -> 1312 raise AttributeError(
#    1313     f"'{type(self).__name__}' object has no attribute '{attr}'"
#    1314 )
#
# AttributeError: 'SeriesGroupBy' object has no attribute 'str'

# %%
country_grp['LanguageHaveWorkedWith'].apply(lambda x: x.str.contains('Python').sum()).loc['India']
# Out:
# 2793

# %%
# it is one way to find the %age of people who worked in python
country_grp['LanguageHaveWorkedWith'].apply(lambda x : x.str.contains('Python').sum()/x.count())*100
# Out:
# Country
# Afghanistan                             37.931034
# Albania                                 34.545455
# Algeria                                 42.168675
# Andorra                                 33.333333
# Angola                                  36.363636
#                                           ...
# Venezuela, Bolivarian Republic of...    40.776699
# Viet Nam                                45.789474
# Yemen                                   44.444444
# Zambia                                  42.307692
# Zimbabwe                                57.575758
# Name: LanguageHaveWorkedWith, Length: 185, dtype: float64

# %%
#another way to find the %age
counrty_respondants = df['Country'].value_counts()

# %%
counrty_respondants

# %%
country_uses_python = country_grp['LanguageHaveWorkedWith'].apply(lambda x:x.str.contains('Python').sum())

# %%
country_uses_python

# %%
python_df = pd.concat([counrty_respondants,country_uses_python], axis = 1,sort=True)

# %%
# python_df.sort_values('Country', ascending = True)
python_df

# %%
python_df.rename(columns = {'count':'Numrespondents','LanguageHaveWorkedWith':'NumKnowsPython'}, inplace = True)

# %%
python_df['percantage'] = (python_df['NumKnowsPython']/python_df['Numrespondents'])*100

# %%
python_df.sort_values(by = 'percantage',ascending = True)

# %%
# it is one way to find the %age of people who worked in python
country_grp['LanguageHaveWorkedWith'].apply(lambda x : x.str.contains('Python').sum()/x.count())*100

# %% [markdown]
# # cleaning data

# %%
pd_people.notna()
# Out:
#    first  last  city  full_name  new_city  first_  last_
# 7   True  True  True      False     False   False  False
# 8   True  True  True      False     False   False  False
# 3   True  True  True       True      True    True   True
# 5   True  True  True      False     False   False  False
# 2   True  True  True       True      True    True   True
# 0   True  True  True       True      True    True   True
# 4   True  True  True      False     False   False  False
# 6   True  True  True      False     False   False  False
# 1   True  True  True       True      True    True   True

# %%
pd_people
# Out:
#       first     last         city       full_name    new_city    first_    last_
# 7     adhil      kvl   malappuram             NaN         NaN       NaN      NaN
# 8     baker      kvl   malappuram             NaN         NaN       NaN      NaN
# 3      alen     jose       idukki       alen jose      IDUKKI      alen     jose
# 5     devil     jose  thoppumpady             NaN         NaN       NaN      NaN
# 2     affef     john   malappuram      affef john  MALAPPURAM     affef     john
# 0  muhammed     amil       iritty   muhammed amil      IRITTY  muhammed     amil
# 4   captain  america      america             NaN         NaN       NaN      NaN
# 6    batman   amalus      wayanad             NaN         NaN       NaN      NaN
# 1    jaseel  abdulla    kasargode  jaseel abdulla   KASARGODE    jaseel  abdulla

# %%
pd_people.drop(columns =['first_','last_'],inplace = True)

# %%
pd_people.loc[0:7,['full_name','new_city']] = 'Missing'

# %%
pd_people
# Out:
#       first     last         city       full_name    new_city
# 7     adhil      kvl   malappuram             NaN         NaN
# 8     baker      kvl   malappuram             NaN         NaN
# 3      alen     jose       idukki       alen jose      IDUKKI
# 5     devil     jose  thoppumpady             NaN         NaN
# 2     affef     john   malappuram      affef john  MALAPPURAM
# 0  muhammed     amil       iritty   muhammed amil      IRITTY
# 4   captain  america      america             NaN         NaN
# 6    batman   amalus      wayanad             NaN         NaN
# 1    jaseel  abdulla    kasargode  jaseel abdulla   KASARGODE

# %%
pd_people.loc[2,'full_name']= None

# %%
pd_people
# Out:
#       first     last         city       full_name    new_city
# 7     adhil      kvl   malappuram             NaN         NaN
# 8     baker      kvl   malappuram             NaN         NaN
# 3      alen     jose       idukki       alen jose      IDUKKI
# 5     devil     jose  thoppumpady             NaN         NaN
# 2     affef     john   malappuram            None  MALAPPURAM
# 0  muhammed     amil       iritty   muhammed amil      IRITTY
# 4   captain  america      america             NaN         NaN
# 6    batman   amalus      wayanad             NaN         NaN
# 1    jaseel  abdulla    kasargode  jaseel abdulla   KASARGODE

# %%
pd_people.dropna()
# Out:
#       first     last       city       full_name   new_city
# 3      alen     jose     idukki       alen jose     IDUKKI
# 0  muhammed     amil     iritty   muhammed amil     IRITTY
# 1    jaseel  abdulla  kasargode  jaseel abdulla  KASARGODE

# %%
# it's actually works when we call dropna()
#how: Specifies the criteria for dropping.

#'any': Drop the row or column if any of its elements are missing.
#'all': Drop the row or column only if all of its elements are missing.
pd_people.dropna(axis = 'index', how = 'any')
# Out:
#       first     last       city       full_name   new_city
# 3      alen     jose     idukki       alen jose     IDUKKI
# 0  muhammed     amil     iritty   muhammed amil     IRITTY
# 1    jaseel  abdulla  kasargode  jaseel abdulla  KASARGODE

# %%
pd_people.dropna(axis = 1, how = 'all')
# Out:
#       first     last         city       full_name    new_city
# 7     adhil      kvl   malappuram             NaN         NaN
# 8     baker      kvl   malappuram             NaN         NaN
# 3      alen     jose       idukki       alen jose      IDUKKI
# 5     devil     jose  thoppumpady             NaN         NaN
# 2     affef     john   malappuram            None  MALAPPURAM
# 0  muhammed     amil       iritty   muhammed amil      IRITTY
# 4   captain  america      america             NaN         NaN
# 6    batman   amalus      wayanad             NaN         NaN
# 1    jaseel  abdulla    kasargode  jaseel abdulla   KASARGODE

# %%
#subset: Specifies a list of columns or index labels to consider when dropping missing values.Only the specified columns or index labels will be examined for missing values, and rows (or columns) containing missing values in these columns will be dropped.
pd_people.dropna(axis = 'index', how = 'any', subset = ['full_name'])

# %%
pd_people.dropna(axis = 'index', how = 'all', subset = ['full_name','city'])

# %%
new_row = pd.DataFrame({
    'first': ['pranav'],
    'last': ['pooran'],
    'city': [None],   
    'full_name': [None]  
})

# %%
pd_people =pd.concat([pd_people,new_row], ignore_index= True)

# %%
pd_people
# Out:
#       first     last         city       full_name    new_city
# 0     adhil      kvl   malappuram             NaN         NaN
# 1     baker      kvl   malappuram             NaN         NaN
# 2      alen     jose       idukki       alen jose      IDUKKI
# 3     devil     jose  thoppumpady             NaN         NaN
# 4     affef     john   malappuram            None  MALAPPURAM
# 5  muhammed     amil       iritty   muhammed amil      IRITTY
# 6   captain  america      america             NaN         NaN
# 7    batman   amalus      wayanad             NaN         NaN
# 8    jaseel  abdulla    kasargode  jaseel abdulla   KASARGODE
# 9    pranav   pooran         None            None         NaN

# %%
pd_people.dropna(axis = 'index', how = 'any', subset = ['full_name','city'])
# Out:
#       first     last         city       full_name    new_city
# 0     adhil      kvl   malappuram             NaN         NaN
# 1     baker      kvl   malappuram             NaN         NaN
# 2      alen     jose       idukki       alen jose      IDUKKI
# 3     devil     jose  thoppumpady             NaN         NaN
# 4     affef     john   malappuram            None  MALAPPURAM
# 5  muhammed     amil       iritty   muhammed amil      IRITTY
# 6   captain  america      america             NaN         NaN
# 7    batman   amalus      wayanad             NaN         NaN
# 8    jaseel  abdulla    kasargode  jaseel abdulla   KASARGODE

# %%
pd_people.replace( 'Missing', np.nan, inplace = True)
pd_people.replace( 'None', np.nan, inplace = True)

# %%
pd_people
# Out:
#       first     last         city       full_name    new_city
# 0     adhil      kvl   malappuram             NaN         NaN
# 1     baker      kvl   malappuram             NaN         NaN
# 2      alen     jose       idukki       alen jose      IDUKKI
# 3     devil     jose  thoppumpady             NaN         NaN
# 4     affef     john   malappuram            None  MALAPPURAM
# 5  muhammed     amil       iritty   muhammed amil      IRITTY
# 6   captain  america      america             NaN         NaN
# 7    batman   amalus      wayanad             NaN         NaN
# 8    jaseel  abdulla    kasargode  jaseel abdulla   KASARGODE
# 9    pranav   pooran         None            None         NaN

# %%
pd_people.dropna()
# Out:
#       first     last       city       full_name   new_city
# 2      alen     jose     idukki       alen jose     IDUKKI
# 5  muhammed     amil     iritty   muhammed amil     IRITTY
# 8    jaseel  abdulla  kasargode  jaseel abdulla  KASARGODE

# %%
pd_people.isna()
# Out:
#    first   last   city  full_name  new_city
# 0  False  False  False       True      True
# 1  False  False  False       True      True
# 2  False  False  False      False     False
# 3  False  False  False       True      True
# 4  False  False  False       True     False
# 5  False  False  False      False     False
# 6  False  False  False       True      True
# 7  False  False  False       True      True
# 8  False  False  False      False     False
# 9  False  False   True       True      True

# %%
pd_people.notna()
# Out:
#    first  last   city  full_name  new_city
# 0   True  True   True      False     False
# 1   True  True   True      False     False
# 2   True  True   True       True      True
# 3   True  True   True      False     False
# 4   True  True   True      False      True
# 5   True  True   True       True      True
# 6   True  True   True      False     False
# 7   True  True   True      False     False
# 8   True  True   True       True      True
# 9   True  True  False      False     False

# %%
#fillna(): Fill missing values with a specified value, method, or strategy
pd_people
# Out:
#   first_name last_name age
# 0       John       Doe  33
# 1       Jane   Unknown  23
# 2    Missing     Smith  22
# 3      Alice     Brown  43

# %%
pd_people.fillna('Missing',inplace =True)

# %% [markdown]
# # casting data types

# %%
pd_people.replace('Missing', np.nan, inplace = True)

# %%
pd_people
# Out:
#   first_name last_name age
# 0       John       Doe  33
# 1       Jane   Unknown  23
# 2    Missing     Smith  22
# 3      Alice     Brown  43

# %%
import pandas as pd

# Example DataFrame
data = {
    'first_name': ['John', 'Jane', None, 'Alice'],
    'last_name': ['Doe', None, 'Smith', 'Brown'],
    'age': [28, 34, None, 45]
}
pd_people = pd.DataFrame(data)

print("Original DataFrame:")
print(pd_people)

# Fill NaN values in the 'first_name' column with 'Missing'
pd_people['first_name'].fillna('Missing', inplace=True)

print("\nDataFrame after filling NaN values in 'first_name' column:")
print(pd_people)

# Fill NaN values in the 'last_name' column with 'Unknown'
pd_people['last_name'].fillna('Unknown', inplace=True)

print("\nDataFrame after filling NaN values in 'last_name' column:")
print(pd_people)
# Out:
# Original DataFrame:
#   first_name last_name   age
# 0       John       Doe  28.0
# 1       Jane      None  34.0
# 2       None     Smith   NaN
# 3      Alice     Brown  45.0
#
# DataFrame after filling NaN values in 'first_name' column:
#   first_name last_name   age
# 0       John       Doe  28.0
# 1       Jane      None  34.0
# 2    Missing     Smith   NaN
# 3      Alice     Brown  45.0
#
# DataFrame after filling NaN values in 'last_name' column:
#   first_name last_name   age
# 0       John       Doe  28.0
# 1       Jane   Unknown  34.0
# 2    Missing     Smith   NaN
# 3      Alice     Brown  45.0

# %%
age = [33, 23, 22, 43,None, 19, 95, None]

# %%
pd_people['age'] = pd.Series(age, dtype = str)

# %%
pd_people.dtypes
# Out:
# first_name    object
# last_name     object
# age           object
# full_name     object
# dtype: object

# %%
pd_people
# Out:
#   first_name last_name age      full_name
# 0       john       doe  33       john doe
# 1       jane   unknown  23   jane unknown
# 2    missing     smith  22  missing smith
# 3      alice     brown  43    alice brown

# %%
pd_people['age'].mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[290], line 1
# ----> 1 pd_people['age'].mean()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\series.py:6225, in Series.mean(self, axis, skipna, numeric_only, **kwargs)
#    6217 @doc(make_doc("mean", ndim=1))
#    6218 def mean(
#    6219     self,
#    (...)
#    6223     **kwargs,
#    6224 ):
# -> 6225     return NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:11992, in NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   11985 def mean(
#   11986     self,
#   11987     axis: Axis | None = 0,
#    (...)
#   11990     **kwargs,
#   11991 ) -> Series | float:
# > 11992     return self._stat_function(
#   11993         "mean", nanops.nanmean, axis, skipna, numeric_only, **kwargs
#   11994     )
#
# ...

# %%
# when we want to find a mean or something then the dtype should be in int or float so if a column having missing values then we have to do replace with missing values to 0 or nan(float) or we have to cast the datatype
pd_people['age']= pd_people['age'].astype(float)

# %%
pd_people.dtypes
# Out:
# first_name     object
# last_name      object
# age           float64
# full_name      object
# dtype: object

# %%
pd_people['age'].mean()
# Out:
# 30.25

# %%
df
# Out:
#        ResponseId     Q120                                         MainBranch                Age                                         Employment RemoteWork                                   CodingActivities                                            EdLevel                                          LearnCode                                    LearnCodeOnline             LearnCodeCoursesCert           YearsCode YearsCodePro                DevType                                            OrgSize                 PurchaseInfluence      TechList                                         BuyNewTool      Country            Currency  CompTotal                             LanguageHaveWorkedWith           LanguageWantToWorkWith                            DatabaseHaveWorkedWith                             DatabaseWantToWorkWith         PlatformHaveWorkedWith                             PlatformWantToWorkWith               WebframeHaveWorkedWith              WebframeWantToWorkWith  \
# ...

# %%
#we can handle the missing values in the beginng itself to control the missing value. for that we have to pass attribute while the file getting loaded so the code for that is
# na_vals = ['NA','Missing']
## here index_col is used to give a default index while loading and it will identify as missing values
#df = pd.read_csv('data_sets/data/survey_results_public.csv',index_col='ResponseId', na_values = na_vals)

# %%
df['YearsCode']
# Out:
# 21497                    25
# 61079                    18
# 26531                     2
# 31396                     4
# 75451    More than 50 years
#                 ...
# 88820                   NaN
# 88828                   NaN
# 88830                   NaN
# 89028                   NaN
# 89159                   NaN
# Name: YearsCode, Length: 89184, dtype: object

# %%
# df['YearsCode'].mean()

# %%
df['YearsCode'] = df['YearsCode'].astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[298], line 1
# ----> 1 df['YearsCode'] = df['YearsCode'].astype(float)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:6534, in NDFrame.astype(self, dtype, copy, errors)
#    6530     results = [ser.astype(dtype, copy=copy) for _, ser in self.items()]
#    6532 else:
#    6533     # else, only a single dtype is given
# -> 6534     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6535     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6536     return res.__finalize__(self, method="astype")
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:414, in BaseBlockManager.astype(self, dtype, copy, errors)
#     411 elif using_copy_on_write():
#     412     copy = False
# --> 414 return self.apply(
#     415     "astype",
#     416     dtype=dtype,
# ...

# %%
df['YearsCode'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of ResponseId
# 21498     25
# 65293      9
# 1335       3
# 33928      5
# 77723      4
#         ...
# 88821    NaN
# 88829    NaN
# 88831    NaN
# 89029    NaN
# 89160    NaN
# Name: YearsCode, Length: 89184, dtype: object>

# %%
df['YearsCode'].unique()
# Out:
# array([nan, '18', '27', '12', '6', '21', '4', '5', '20', '14', '10', '15',
#        '11', '3', '24', '8', '13', 'Less than 1 year', '16', '33', '22',
#        '30', '32', '7', '35', '28', '40', '17', '29', '19',
#        'More than 50 years', '9', '38', '26', '34', '25', '2', '45', '23',
#        '31', '43', '1', '48', '41', '50', '39', '42', '37', '36', '44',
#        '46', '49', '47'], dtype=object)

# %%
df['YearsCode'].replace('More than 50 years',51, inplace = True)

# %%
df['YearsCode'].replace( 'Less than 1 year',0, inplace = True)

# %%
df['YearsCode']= df['YearsCode'].astype(float)

# %%
df['YearsCode'].mean()
# Out:
# 13.966855378281009

# %%
df['YearsCode'].median()
# Out:
# 11.0
